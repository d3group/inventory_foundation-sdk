# %% [markdown]
# # Database management
#
# > Classes and functions for managing access to the databases

# %%
#| default_exp db_mgmt

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export

from kedro.config import OmegaConfigLoader
from kedro.framework.project import settings
from pathlib import Path

# %%
#| export

def get_db_credentials():
    
    """
    Fetch PostgreSQL database credentials from the configuration file of the kedro project.

    Uses `OmegaConfigLoader` to load credentials stored under `credentials.postgres`.

    Returns:
        dict: A dictionary with the database connection details (e.g., host, port, user, password, dbname).
    """

    conf_path = str(Path(settings.CONF_SOURCE))
    conf_loader = OmegaConfigLoader(conf_source=conf_path)
    db_credentials = conf_loader["credentials"]["postgres"]

    return db_credentials

# %%
#| hide
import nbdev; nbdev.nbdev_export()
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:2                                                                                    │
# │                                                                                                  │
# │   1 #| hide                                                                                      │
# │ ❱ 2 import nbdev; nbdev.nbdev_export()                                                           │
# │   3                                                                                              │
# │                                                                                                  │
# │ /Users/magnus/miniforge3/envs/inventory_foundation/lib/python3.11/site-packages/fastcore/script. │
# │ py:112 in _f                                                                                     │
# │                                                                                                  │
# │   109 │   @wraps(func)                                                                           │
# │   110 │   def _f(*args, **kwargs):                                                               │
# │   111 │   │   mod = inspect.getmodule(inspect.currentframe().f_back)                             │
# │ ❱ 112 │   │   if not mod: return func(*args, **kwargs)                                           │
# │   113 │   │   if not SCRIPT_INFO.func and mod.__name__=="__main__": SCRIPT_INFO.func = func.__   │
# │   114 │   │   if len(sys.argv)>1 and sys.argv[1]=='': sys.argv.pop(1)                            │
# │   115 │   │   p = anno_parser(func)                                                              │
# │                                                                                                  │
# │ /Users/magnus/miniforge3/envs/inventory_foundation/lib/python3.11/site-packages/nbdev/doclinks.p │
# │ y:155 in nbdev_export                                                                            │
# │                                                                                                  │
# │   152 │   │   import nbdev.export                                                                │
# │   153 │   │   procs = [getattr(nbdev.export, p) for p in L(procs)]                               │
# │   154 │   files = nbglob(path=path, as_path=True, **kwargs).sorted('name')                       │
# │ ❱ 155 │   for f in files: nb_export(f, procs=procs)                                              │
# │   156 │   add_init(get_config().lib_path)                                                        │
# │   157 │   _build_modidx()                                                                        │
# │   158                                                                                            │
# │                                                                                                  │
# │ /Users/magnus/miniforge3/envs/inventory_foundation/lib/python3.11/site-packages/nbdev/export.py: │
# │ 92 in nb_export                                                                                  │
# │                                                                                                  │
# │   89 │   │   │   │   │    "See https://nbdev.fast.ai/getting_started.html for more informatio    │
# │   90 │   │   │   │   return                                                                      │
# │   91 │   │   │   mm = mod_maker(dest=lib_path, name=nm, nb_path=nbname, is_new=bool(name) or     │
# │ ❱ 92 │   │   │   mm.make(cells, all_cells, lib_path=lib_path)                                    │
# │   93                                                                                             │
# │                                                                                                  │
# │ /Users/magnus/miniforge3/envs/inventory_foundation/lib/python3.11/site-packages/nbdev/maker.py:1 │
# │ 97 in make                                                                                       │
# │                                                                                                  │
# │   194 │   if self.parse:                                                                         │
# │   195 │   │   if not lib_path: lib_path = get_config().lib_path                                  │
# │   196 │   │   mod_dir = os.path.relpath(self.fname.parent, Path(lib_path).parent)                │
# │ ❱ 197 │   │   _import2relative(all_cells, mod_dir)                                               │
# │   198 │   if not self.is_new: return self._make_exists(cells, all_cells)                         │
# │   199 │                                                                                          │
# │   200 │   self.fname.parent.mkdir(exist_ok=True, parents=True)                                   │
# │                                                                                                  │
# │ /Users/magnus/miniforge3/envs/inventory_foundation/lib/python3.11/site-packages/nbdev/maker.py:1 │
# │ 76 in _import2relative                                                                           │
# │                                                                                                  │
# │   173 def _import2relative(cells, lib_name=None):                                                │
# │   174 │   "Converts `cells` to use `import2relative` based on `lib_name`"                        │
# │   175 │   if lib_name is None: lib_name = get_config().lib_name                                  │
# │ ❱ 176 │   for cell in cells: cell.import2relative(lib_name)                                      │
# │   177                                                                                            │
# │   178 # %% ../nbs/api/02_maker.ipynb                                                             │
# │   179 def _retr_mdoc(cells):                                                                     │
# │                                                                                                  │
# │ /Users/magnus/miniforge3/envs/inventory_foundation/lib/python3.11/site-packages/nbdev/maker.py:1 │
# │ 60 in import2relative                                                                            │
# │                                                                                                  │
# │   157                                                                                            │
# │   158 @patch                                                                                     │
# │   159 def import2relative(cell:NbCell, libname):                                                 │
# │ ❱ 160 │   src = update_import(cell.source, cell.parsed_(), libname)                              │
# │   161 │   if src: cell.set_source(src)                                                           │
# │   162                                                                                            │
# │   163 # %% ../nbs/api/02_maker.ipynb                                                             │
# │                                                                                                  │
# │ /Users/magnus/miniforge3/envs/inventory_foundation/lib/python3.11/site-packages/nbdev/maker.py:1 │
# │ 51 in update_import                                                                              │
# │                                                                                                  │
# │   148 │   if not imps: return                                                                    │
# │   149 │   src = source.splitlines(True)                                                          │
# │   150 │   for imp in imps:                                                                       │
# │ ❱ 151 │   │   nmod = f(imp.module, libname, imp.level)                                           │
# │   152 │   │   lin = imp.lineno-1                                                                 │
# │   153 │   │   sec = src[lin][imp.col_offset:imp.end_col_offset]                                  │
# │   154 │   │   newsec = re.sub(f"(from +){'.'*imp.level}{imp.module or ''}", fr"\1{nmod}", sec)   │
# │                                                                                                  │
# │ /Users/magnus/miniforge3/envs/inventory_foundation/lib/python3.11/site-packages/nbdev/maker.py:1 │
# │ 16 in relative_import                                                                            │
# │                                                                                                  │
# │   113 # %% ../nbs/api/02_maker.ipynb                                                             │
# │   114 def relative_import(name, fname, level=0):                                                 │
# │   115 │   "Convert a module `name` to a name relative to `fname`"                                │
# │ ❱ 116 │   assert not level                                                                       │
# │   117 │   sname = name.replace('.','/')                                                          │
# │   118 │   if not(os.path.commonpath([sname,fname])): return name                                 │
# │   119 │   rel = os.path.relpath(sname, fname)                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# AssertionError
